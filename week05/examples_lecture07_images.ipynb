# %%
from PIL import Image

# %%
Image
# Out:
# <module 'PIL.Image' from '/data/data/com.termux/files/usr/lib/python3.6/site-packages/PIL/Image.py'>

# %%
poochie = Image.open("/home/storage/downloads/wherespoochie.jpg")

# %%
poochie.info
# Out:
# {}

# %%
hi = Image.open("hi.png")
hi.info
# Out:
# {'Software': 'matplotlib version 2.1.1, http://matplotlib.org/',
#  'dpi': (72, 72)}

# %%
poochie.info['memes'] = 'awesome'

# %%
poochie.save("poochie2.jpg")

# %%
poochie.save("poochie3.png")

# %%
Image.open("poochie2.jpg").info
# Out:
# {'jfif': 257, 'jfif_density': (1, 1), 'jfif_unit': 0, 'jfif_version': (1, 1)}

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(poochie)

# %%
import numpy as np

# %%
poochie_array = np.array(poochie)

# %%
poochie_array.shape
# Out:
# (480, 640, 3)

# %%
import yt

# %%
plt.imshow(poochie_array[:,:,0], cmap='Reds_r')
plt.colorbar()

# %%
plt.imshow(poochie_array[:,:,1], cmap='Greens_r')
plt.colorbar()

# %%
plt.imshow(poochie_array[:,:,2], cmap='Blues_r')
plt.colorbar()

# %%
plt.imshow(poochie_array)

# %%
poochie_array.shape
# Out:
# (480, 640, 3)

# %%
reds = poochie_array[:,:,0]

# %%
greens = poochie_array[:,:,1]

# %%
blues = poochie_array[:,:,2]

# %%
reds.min(), reds.max()
# Out:
# (0, 255)

# %%
plt.hist(reds.ravel(), bins=256, color='r', alpha = 0.25);

# %%
plt.hist(greens.ravel(), bins=256, color='g', alpha = 0.25);

# %%
plt.hist(blues.ravel(), bins=256, color='b', alpha = 0.25);

# %%
plt.hist(reds.ravel(), bins=256, color='r', alpha=0.33);
plt.hist(greens.ravel(), bins=256, color='g', alpha=0.33);
plt.hist(blues.ravel(), bins=256, color='b', alpha=0.33);
