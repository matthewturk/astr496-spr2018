# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
class LetYourImaginationBeYourGuide:
    pass

# %%
obj = LetYourImaginationBeYourGuide()

# %%
obj.this_class = "rules"

# %%
obj.this_class
# Out:
# 'rules'

# %%
import numpy as np

# %%
class MyDataset:
    def __init__(self, size):
        self.data = np.random.random(size)
        self.size = size
        
    def __add__(self, other):
        obj = MyDataset(self.size)
        obj.data = self.data + other.data
        return obj
    
    def plot(self, filename, ylabel = "", xlabel="x"):
        plt.clf()
        plt.plot(self.data)
        plt.ylabel(ylabel)
        plt.xlabel(xlabel)
        plt.savefig(filename)
    
    def __repr__(self):
        return "Hi there!"

# %%
my_dataset = MyDataset(128)

# %%
my_dataset.plot("hi.png", xlabel = "my_x")

# %%
my_other_dataset = MyDataset(128)

# %%
my_dataset.data[0], my_other_dataset.data[0]
# Out:
# (0.00999977158024834, 0.31556579795216644)

# %%
print(my_dataset)
# Out:
# <__main__.MyDataset object at 0x7d495b466cc0>

# %%
my_dataset + my_other_dataset

# %%
a = MyDataset(128)
b = MyDataset(256)
c = a + b
d = b + a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-ec41f8b599c3> in <module>()
#       1 a = MyDataset(128)
#       2 b = MyDataset(256)
# ----> 3 c = a + b
#       4 d = b + a
#
# <ipython-input-45-62ae89842f71> in __add__(self, other)
#       6     def __add__(self, other):
#       7         obj = MyDataset(self.size)
# ----> 8         obj.data = self.data + other.data
#       9         return obj
#
# ValueError: operands could not be broadcast together with shapes (128,) (256,)

# %%
class BigMistake:
    def __init__(self, default_values = []):
        self.default_values = default_values[:]

# %%
mistake1 = BigMistake()
mistake2 = BigMistake()

# %%
mistake1.
# Out:
# {1: 2}

# %%
mistake2.something_else
# Out:
# {1: 2}

# %%
mistake1.something_else[3] = 4

# %%
mistake2.something_else
# Out:
# {1: 2, 3: 4}

# %%
mistake1.something_else is mistake2.something_else
# Out:
# True

# %%
mistake1.default_values.append(" SPOILER ALERT ")

# %%
mistake1.default_values
# Out:
# [' SPOILER ALERT ']

# %%
mistake2.default_values
# Out:
# [' SPOILER ALERT ']
